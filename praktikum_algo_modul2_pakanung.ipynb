# %% [markdown]
# <a href="https://colab.research.google.com/github/FaradinaKusuma/praktikum.algoritma.semester1.pakanung/blob/main/praktikum_algo_modul2_pakanung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#faradina kusuma 065002500035
#praktikum 2

a = int(input("Masukkan nilai a: "))
b = int(input("Masukkan nilai b: "))

jumblah = a + b
selisih = a - b
kali = a * b
sisa = a % b
bagi = a / b
pangkat = a ** b

print("Jumlah dari a dan b adalah", jumblah)
print("Selisih dari a dan b adalah", selisih)
print("Hasil perkalian dari a dan b adalah", kali)
print("Hasil sisa bagi dari a dan b adalah", sisa)
print("Hasil pembagian dari a dan b adalah", bagi)
print("Hasil pangkat dari a dan b adalah", pangkat)

import math
math.log(a)
# Out:
# Masukkan nilai a: 5
# Masukkan nilai b: 6
# Jumlah dari a dan b adalah 11
# Selisih dari a dan b adalah -1
# Hasil perkalian dari a dan b adalah 30
# Hasil sisa bagi dari a dan b adalah 5
# Hasil pembagian dari a dan b adalah 0.8333333333333334
# Hasil pangkat dari a dan b adalah 15625
# 1.6094379124341003

# %%
import math
a= 5
b= 6
math.log(a)
# Out:
# 1.6094379124341003

# %%
#faradina kusuma
#065002500035

import math
math.radians(180)
math.sin(180)
math.cos(180)
math.atan2
math.sqrt(16)

print("Masukkan lattitude dan longitudenya untuk menentukan jarak antara 2 titik:")

R = 6371

kota1 = input("Masukkan nama kota pertama: ")
kota2 = input("Masukkan nama kota kedua: ")

lat1 = float(input("Masukkan lattitude pertama: "))
long1 = float(input("Masukkan longitudenya: "))
lat2 = float(input("Masukkan lattitude kedua: "))
long2 = float(input("Masukkan longitudenya: "))

lat1 = math.radians(lat1)
long1 = math.radians(long1)
lat2 = math.radians(lat2)
long2 = math.radians(long2)

selisih_lat = lat2 - lat1
selisih_long = long2 - long1

a = math.sin(selisih_lat/2)**2 + math.cos(lat1)*math.cos(lat2)*math.sin(selisih_long/2)**2
import math
c = 2* math.atan2(math.sqrt (a),math.sqrt(1-a))
d = R*c

print("Jarak antara", kota1, "dan", kota2, "adalah", d, "km")
# Out:
# Masukkan lattitude dan longitudenya untuk menentukan jarak antara 2 titik:
# Masukkan nama kota pertama: jakarta
# Masukkan nama kota kedua: bandung
# Masukkan lattitude pertama: -6.200000
# Masukkan longitudenya: 106.816666
# Masukkan lattitude kedua: -6.914744
# Masukkan longitudenya: 107.609810
# Jarak antara jakarta dan bandung adalah 118.29196053744997 km
