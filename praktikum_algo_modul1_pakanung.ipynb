# %% [markdown]
# <a href="https://colab.research.google.com/github/FaradinaKusuma/praktikum.algoritma.semester1.pakanung/blob/main/praktikum_algo_modul1_pakanung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Faradina Kusuma
#065002500035
#Praktikum Algoritma Elemen Kompetensi 1

name = input("Masukkan nama lengkap: ")
print(name)
tempat = input("Masukka tempat tinggal: ")
print(tempat)
kampus = input("masukkan nama kampus:" )
print(kampus)
jurusan = input("masukkan nama jurusan:" )
print(jurusan)
gedung = input("Dimana gedung kampus kamu berada:" )
print(gedung)

print(f"Hallo nama Saya {name}, Saya tinggal di {tempat}, Saya kuliah di" )
print(f"{kampus} jurusan {jurusan} di {gedung}, dan Saya siap ikut praktikum Algoritma." )
# Out:
# Masukkan nama lengkap: Faradina Kusuma
# Faradina Kusuma
# Masukka tempat tinggal: Cibubur
# Cibubur
# masukkan nama kampus:Trisakti
# Trisakti
# masukkan nama jurusan:Sistem Informasi
# Sistem Informasi
# Dimana gedung kampus kamu berada:Gedung E
# Gedung E
# Hallo nama Saya Faradina Kusuma, Saya tinggal di Cibubur, Saya kuliah di
# Trisakti jurusan Sistem Informasi di Gedung E, dan Saya siap ikut praktikum Algoritma.

# %%
#Faradina Kusuma
#065002500035
#Praktikum Algoritma Elemen Kompetensi 1

panjang_ruangan = int(input("Masukkan panjang ruangan: (dalam satuan meter)"))
lebar_ruangan = int(input("Masukkan lebar ruangan: (dalam satuan meter)"))
luas_ruangan = panjang_ruangan * lebar_ruangan
print(luas_ruangan)
# Out:
# Masukkan panjang ruangan: (dalam satuan meter)10
# Masukkan lebar ruangan: (dalam satuan meter)10
# 100

# %%
#Faradina Kusuma
#065002500035
#Praktikum Algoritma Elemen Kompetensi 1

nama = input("Masukkan nama: ")
tinggi = int (input("Masukkan tinggi badan (dalam centimeter): "))
berat = int (input("Masukkan berat badan (dalam kg): "))
BMI = berat / tinggi**2 *10000
print(f" BMI = {BMI: .2f}")
# Out:
# Masukkan nama: rrr
# Masukkan tinggi badan (dalam centimeter): 161
# Masukkan berat badan (dalam kg): 50
#  BMI =  19.29
