# %% [markdown]
# <a href="https://colab.research.google.com/github/FaradinaKusuma/praktikum.algoritma.semester1.pakanung/blob/main/praktikum_algo_modul3_pakanung.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Faradina kusuma
#065002500035
#realtime modul 3

a= int(input("Masukkan sisi a: "))
b= int(input("Masukkan sisi b: "))
c= int(input("Masukkan sisi c: "))

if (a + b > c) and (a + c > b) and (b + c > a):
 if a == b == c:
    print("Segitiga sama sisi")
 elif a == b or b == c:
    print("Segitiga sama kaki")
 elif a != b != c:
    print("Segitiga sembarang")
else:
  print('bukan segitiga')
# Out:
# Masukkan sisi a: 7
# Masukkan sisi b: 9
# Masukkan sisi c: 10
# Segitiga sembarang
